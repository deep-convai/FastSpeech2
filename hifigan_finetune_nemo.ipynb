# %%
#imports
import random
import os
import json
import librosa
from tqdm import tqdm

import torch
import IPython.display as ipd
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt
from pathlib import Path

from model import FastSpeech2
from nemo.collections.tts.models import HifiGanModel
from nemo.collections.tts.parts.utils.tts_dataset_utils import BetaBinomialInterpolator
import soundfile as sf
import numpy as np
# Out:
# [NeMo W 2023-07-28 00:32:44 experimental:27] Module <class 'nemo.collections.asr.modules.audio_modules.SpectrogramToMultichannelFeatures'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-07-28 00:32:44 experimental:27] Module <class 'nemo.collections.tts.parts.utils.callbacks.LoggingCallback'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-07-28 00:32:44 experimental:27] Module <class 'nemo.collections.tts.models.fastpitch_ssl.FastPitchModel_SSL'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-07-28 00:32:44 experimental:27] Module <class 'nemo.collections.common.tokenizers.text_to_speech.tts_tokenizers.IPATokenizer'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-07-28 00:32:44 experimental:27] Module <class 'nemo.collections.tts.models.radtts.RadTTSModel'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-07-28 00:32:44 experimental:27] Module <class 'nemo.collections.tts.models.ssl_tts.SSLDisentangler'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-07-28 00:32:44 experimental:27] Module <class 'nemo.collections.tts.models.vits.VitsModel'> is experimental, not ready for production and is not fully supported. Use at your own risk.

# %%
import yaml
model_config = yaml.load(open('/workspace/nemo/vol/FastSpeech2/config/RAVDESS/model.yaml',
                              "r"), Loader=yaml.FullLoader)
preprocess_config = yaml.load(open('/workspace/nemo/vol/FastSpeech2/config/RAVDESS/preprocess.yaml',
                              "r"), Loader=yaml.FullLoader)

# %%
fp = FastSpeech2(model_config=model_config, preprocess_config=preprocess_config)
ckpt_file_path = '/workspace/nemo/vol/FastSpeech2/output/ckpt/RAVDESS/800000.pth.tar'
checkpoint = torch.load(ckpt_file_path, map_location=torch.device('cuda'))
fp.load_state_dict(checkpoint['model'])
fp = fp.to('cuda')

# %%
#helper functions
def load_wav(audio_file, target_sr=None):
    with sf.SoundFile(audio_file, 'r') as f:
        samples = f.read(dtype='float32')
        sample_rate = f.samplerate
        if target_sr is not None and target_sr != sample_rate:
            samples = librosa.core.resample(samples, orig_sr=sample_rate, target_sr=target_sr)
    return samples.transpose()

# %%
voices_path = 'raw_data/RAVDESS/'
speaker = 'josh'
base_path = os.path.join(voices_path, speaker)
speakers_path = "preprocessed_data/RAVDESS/speakers.json"
emotions_path = "preprocessed_data/RAVDESS/emotions.json"

rec = []

for emotion in os.listdir(base_path):
    emotion_path = os.path.join(base_path, emotion)
    for file in os.listdir(emotion_path):
        filename = file.split('.')[0]
        audio_filepath = os.path.join(emotion_path, '.'.join([filename, 'wav'])) 
        text_filepath = os.path.join(emotion_path, '.'.join([filename, 'lab']))
        duration = librosa.get_duration(filename=audio_filepath)
        with open(text_filepath, 'r') as f:
            text = f.read()
        with open(speakers_path, "r") as f:
            speakers = json.load(f)
            speaker_ = [v for k,v in speakers.items() if k==speaker][0]
        with open(emotions_path, "r") as f:
            emotions = json.load(f)
            emotion_ = [v for k,v in emotions.items() if k==emotion][0]   
        r = {
           "audio_filepath" : audio_filepath,
           "text" : text,
           "speaker": speaker_,
           "emotion": emotion_,
           "duration" : round(duration,1),
           "text_no_preprocessing" : text
        }
        rec.append(r)
random.shuffle(rec)
train_len = int(0.9*len(rec))
train_rec = rec[:train_len]
val_rec = rec[train_len:]

# %%
train_manifest = f'./fastpitch_train.json'
with open(train_manifest, "w") as f:
    for s in train_rec:
        f.write(json.dumps(s) + '\n')
        
val_manifest = f'./fastpitch_val.json'
with open(val_manifest, "w") as f:
    for s in val_rec:
        f.write(json.dumps(s) + '\n')

# %%
train_rec[0]
# Out:
# {'audio_filepath': 'raw_data/RAVDESS/josh/neutral/neutral_225-252_0238.wav',
#  'text': ' it happened to him at the garland society in oaklands one afternoon.',
#  'speaker': 1,
#  'emotion': 4,
#  'duration': 5.2,
#  'text_no_preprocessing': ' it happened to him at the garland society in oaklands one afternoon.'}

# %%
from synthesize import preprocess_english

def create_hifigan_finetune_data(records, speaker, run= 'train', device='cuda'):    
    beta_binomial_interpolator = BetaBinomialInterpolator()

    save_dir = Path(f"/workspace/nemo/vol/FastSpeech2/mels/{speaker}_{run}")
    save_dir.mkdir(exist_ok=True, parents=True)

    # Generate a spectrograms (we need to use ground truth alignment for correct matching between audio and mels)
    for i, r in tqdm(enumerate(records)):
        audio = load_wav(r["audio_filepath"])
        audio = torch.from_numpy(audio).unsqueeze(0).to(device)
        audio_len = torch.tensor(audio.shape[1], dtype=torch.long, device=device).unsqueeze(0)


        with torch.no_grad():
            text = r['text']
            speaker = r['speaker']
            emotion = r['emotion']
            ids = raw_texts = [text[:100]]
            speaker = torch.tensor([speaker]).to('cuda')
            emotion = torch.tensor([emotion]).to('cuda') 
            texts = torch.tensor([preprocess_english(text, preprocess_config)]).to('cuda')
            text_lens = torch.tensor([len(texts[0])]).to('cuda')
            batchs = [(ids, raw_texts, speaker, emotion, texts, text_lens, max(text_lens))]
            predictions = fp(*(batchs[0][2:]))
            spectrogram = predictions[1].transpose(1, 2)

    #         if "normalized_text" in r:
    #             text = spec_model.parse(r["normalized_text"], normalize=False)
    #         else:
    #             text = spec_model.parse(r['text'])

    #         text_len = torch.tensor(text.shape[-1], dtype=torch.long, device=device).unsqueeze(0)

    #         spect, spect_len = spec_model.preprocessor(input_signal=audio, length=audio_len)

    #         # Generate attention prior and spectrogram inputs for HiFi-GAN
    #         attn_prior = torch.from_numpy(
    #           beta_binomial_interpolator(spect_len.item(), text_len.item())
    #         ).unsqueeze(0).to(text.device)

    #         spectrogram = spec_model.forward(
    #           text=text, 
    #           input_lens=text_len, 
    #           spec=spect, 
    #           mel_lens=spect_len, 
    #           attn_prior=attn_prior,
    #         )[0]

            save_path = save_dir / f"mel_{i}.npy"
            np.save(save_path, spectrogram[0].to('cpu').numpy())
            r["mel_filepath"] = str(save_path)

    hifigan_manifest_path = f"./hifigan_{run}_ft.json"
    with open(hifigan_manifest_path, "w") as f:
        for r in records:
            f.write(json.dumps(r) + '\n')

# %%
create_hifigan_finetune_data(train_rec, 'josh', 'train', 'cuda')
# Out:
# 1553it [19:10,  1.35it/s]

# %%
create_hifigan_finetune_data(val_rec, 'josh', 'val', 'cuda')
# Out:
# 173it [02:08,  1.35it/s]

# %%
! cd hifigan_conf && unzip hifigan.zip
! cd hifigan_conf && cd hifigan && wget https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/conf/hifigan/hifigan.yaml && cd ..
# Out:
# Archive:  hifigan.zip
#    creating: hifigan/
#    creating: hifigan/model/
#    creating: hifigan/model/validation_ds/
#  extracting: hifigan/model/validation_ds/val_ds.yaml
#  extracting: hifigan/model/validation_ds/val_ds_finetune.yaml
#    creating: hifigan/model/train_ds/
#  extracting: hifigan/model/train_ds/train_ds.yaml
#  extracting: hifigan/model/train_ds/train_ds_finetune.yaml
#    creating: hifigan/model/generator/
#  extracting: hifigan/model/generator/v1.yaml
#  extracting: hifigan/model/generator/v1_44100.yaml
#  extracting: hifigan/model/generator/v2.yaml
#  extracting: hifigan/model/generator/v3.yaml
#  extracting: hifigan/hifigan.yaml
#  extracting: hifigan/hifigan_44100.yaml
# --2023-07-28 01:28:08--  https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/conf/hifigan/hifigan.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2244 (2.2K) [text/plain]
# Saving to: ‘hifigan.yaml.1’
#
# hifigan.yaml.1      100%[===================>]   2.19K  --.-KB/s    in 0s
#
# 2023-07-28 01:28:08 (154 MB/s) - ‘hifigan.yaml.1’ saved [2244/2244]

# %%
home_path = !(echo $HOME)
home_path = home_path[0]
print(home_path)

nemo_files = [p for p in Path(f"{home_path}/.cache/torch/NeMo/").glob("**/tts_hifigan.nemo")]
print(f"Copying {nemo_files[0]} to ./")
Path("./tts_hifigan.nemo").write_bytes(nemo_files[0].read_bytes())
# Out:
# /root
# Copying /root/.cache/torch/NeMo/NeMo_1.19.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo to ./
# 315386678

# %%
#!pip install wandb -qU
#import wandb
#wandb.login()

# %%
wandb_api_key = "108bad0089a140932fbbe1c9e2ae182a1a228ffe"
#wandb.login()

# %%
# !wget https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/hifigan_finetune.py
# Out:
# --2023-07-28 01:31:09--  https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/hifigan_finetune.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1192 (1.2K) [text/plain]
# Saving to: ‘hifigan_finetune.py’
#
# hifigan_finetune.py 100%[===================>]   1.16K  --.-KB/s    in 0s
#
# 2023-07-28 01:31:09 (261 MB/s) - ‘hifigan_finetune.py’ saved [1192/1192]

# %%
!(HYDRA_FULL_ERROR=1 python hifigan_finetune.py \
--config-name=hifigan.yaml \
model.train_ds.dataloader_params.batch_size=32 \
model.max_steps=100000 \
model.optim.lr=1e-4 \
~model.optim.sched \
train_dataset=hifigan_train_ft.json \
validation_datasets=hifigan_val_ft.json \
exp_manager.exp_dir=hifigan_ft \
+init_from_pretrained_model=nvidia/tts_hifigan \
trainer.check_val_every_n_epoch=5 \
trainer.log_every_n_steps=3 \
)
# exp_manager.create_wandb_logger=true \
# exp_manager.wandb_logger_kwargs.name='Josh_emotional_HG' \
# exp_manager.wandb_logger_kwargs.project="TTS_convai"  \
# model/train_ds=train_ds_finetune \
# model/validation_ds=val_ds_finetune \
# Out:
# [NeMo W 2023-07-28 02:15:51 experimental:27] Module <class 'nemo.collections.asr.modules.audio_modules.SpectrogramToMultichannelFeatures'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-07-28 02:15:51 experimental:27] Module <class 'nemo.collections.tts.parts.utils.callbacks.LoggingCallback'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-07-28 02:15:51 experimental:27] Module <class 'nemo.collections.tts.models.fastpitch_ssl.FastPitchModel_SSL'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-07-28 02:15:51 experimental:27] Module <class 'nemo.collections.common.tokenizers.text_to_speech.tts_tokenizers.IPATokenizer'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-07-28 02:15:51 experimental:27] Module <class 'nemo.collections.tts.models.radtts.RadTTSModel'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-07-28 02:15:51 experimental:27] Module <class 'nemo.collections.tts.models.ssl_tts.SSLDisentangler'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-07-28 02:15:51 experimental:27] Module <class 'nemo.collections.tts.models.vits.VitsModel'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-07-28 02:15:51 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'hifigan.yaml': Defaults list is missing `_self_`. See https://hydra.cc/docs/upgrades/1.0_to_1.1/default_composition_order for more information
#       warnings.warn(msg, UserWarning)
#
# [NeMo W 2023-07-28 02:15:51 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
#     See https://hydra.cc/docs/next/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#       ret = run_job(
#
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [NeMo I 2023-07-28 02:15:51 exp_manager:374] Experiments will be logged at hifigan_ft/HifiGan/2023-07-28_02-15-51
# [NeMo I 2023-07-28 02:15:51 exp_manager:797] TensorboardLogger has been set up
# [NeMo W 2023-07-28 02:15:51 exp_manager:893] The checkpoint callback was told to monitor a validation value and trainer's max_steps was set to 100000. Please ensure that max_steps will run for at least 5 epochs to ensure that checkpointing will not error out.
# [NeMo I 2023-07-28 02:15:51 data:1068] Loading dataset from hifigan_train_ft.json.
# 1553it [00:00, 545494.86it/s]
# [NeMo I 2023-07-28 02:15:51 data:1092] Loaded dataset with 1553 files.
# [NeMo I 2023-07-28 02:15:51 data:1094] Dataset contains 1.75 hours.
# [NeMo I 2023-07-28 02:15:51 data:376] Pruned 0 files. Final dataset contains 1553 files
# [NeMo I 2023-07-28 02:15:51 data:378] Pruned 0.00 hours. Final dataset contains 1.75 hours.
# [NeMo I 2023-07-28 02:15:51 data:1068] Loading dataset from hifigan_val_ft.json.
# 173it [00:00, 477692.29it/s]
# [NeMo I 2023-07-28 02:15:51 data:1092] Loaded dataset with 173 files.
# [NeMo I 2023-07-28 02:15:51 data:1094] Dataset contains 0.20 hours.
# [NeMo I 2023-07-28 02:15:51 data:376] Pruned 23 files. Final dataset contains 150 files
# [NeMo I 2023-07-28 02:15:51 data:378] Pruned 0.02 hours. Final dataset contains 0.18 hours.
# [NeMo I 2023-07-28 02:15:51 features:291] PADDING: 0
# [NeMo I 2023-07-28 02:15:51 features:299] STFT using exact pad
# [NeMo I 2023-07-28 02:15:51 features:291] PADDING: 0
# [NeMo I 2023-07-28 02:15:51 features:299] STFT using exact pad
# Downloading tts_hifigan.nemo: 100%|███████████| 315M/315M [00:02<00:00, 115MB/s]
# [NeMo W 2023-07-28 02:15:56 modelPT:161] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/train_finetune.txt
#       min_duration: 0.75
#       n_segments: 8192
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 64
#       num_workers: 4
#
# [NeMo W 2023-07-28 02:15:56 modelPT:168] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/val_finetune.txt
#       min_duration: 3
#       n_segments: 66150
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 5
#       num_workers: 4
#
# [NeMo W 2023-07-28 02:15:56 features:268] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2023-07-28 02:15:56 features:291] PADDING: 0
# [NeMo W 2023-07-28 02:15:56 features:268] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2023-07-28 02:15:56 features:291] PADDING: 0
# [NeMo I 2023-07-28 02:15:56 save_restore_connector:249] Model HifiGanModel was successfully restored from /root/.cache/huggingface/hub/models--nvidia--tts_hifigan/snapshots/3ba1fed954276287015654bf4c78060ffc9a4772/tts_hifigan.nemo.
# [NeMo I 2023-07-28 02:15:56 modelPT:1268] Model checkpoint restored from pretrained checkpoint with name : `nvidia/tts_hifigan`
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# Added key: store_based_barrier_key:1 to store for rank: 0
# Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 1 nodes.
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name                       | Type                     | Params
# ------------------------------------------------------------------------
# 0 | audio_to_melspec_precessor | FilterbankFeatures       | 0
# 1 | trg_melspec_fn             | FilterbankFeatures       | 0
# 2 | generator                  | Generator                | 13.9 M
# 3 | mpd                        | MultiPeriodDiscriminator | 41.1 M
# 4 | msd                        | MultiScaleDiscriminator  | 29.6 M
# 5 | feature_loss               | FeatureMatchingLoss      | 0
# 6 | discriminator_loss         | DiscriminatorLoss        | 0
# 7 | generator_loss             | GeneratorLoss            | 0
# ------------------------------------------------------------------------
# 84.7 M    Trainable params
# 0         Non-trainable params
# 84.7 M    Total params
# 338.643   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s][NeMo W 2023-07-28 02:15:57 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 32 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#       rank_zero_warn(
#
# Epoch 0:   0%|                                           | 0/49 [00:00<?, ?it/s][W reducer.cpp:1300] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# [NeMo W 2023-07-28 02:15:59 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:232: UserWarning: You called `self.log('global_step', ...)` in your `training_step` but the value needs to be floating point. Converting it to torch.float32.
#       warning_cache.warn(
#
# Epoch 4:  83%|████▏| 49/59 [00:17<00:03,  2.85it/s, v_num=5-51, g_l1_loss=0.333]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 4:  85%|████▏| 50/59 [00:17<00:03,  2.88it/s, v_num=5-51, g_l1_loss=0.333]
# Epoch 4:  86%|████▎| 51/59 [00:17<00:02,  2.92it/s, v_num=5-51, g_l1_loss=0.333]
# Epoch 4:  88%|████▍| 52/59 [00:17<00:02,  2.96it/s, v_num=5-51, g_l1_loss=0.333]
# Epoch 4:  90%|████▍| 53/59 [00:17<00:02,  2.99it/s, v_num=5-51, g_l1_loss=0.333]
# Epoch 4:  92%|████▌| 54/59 [00:17<00:01,  3.02it/s, v_num=5-51, g_l1_loss=0.333]
# Epoch 4:  93%|████▋| 55/59 [00:18<00:01,  3.05it/s, v_num=5-51, g_l1_loss=0.333]
# Epoch 4:  95%|████▋| 56/59 [00:18<00:00,  3.09it/s, v_num=5-51, g_l1_loss=0.333]
# Epoch 4:  97%|████▊| 57/59 [00:18<00:00,  3.13it/s, v_num=5-51, g_l1_loss=0.333]
# Epoch 4:  98%|████▉| 58/59 [00:18<00:00,  3.16it/s, v_num=5-51, g_l1_loss=0.333]
# Epoch 4: 100%|█████| 59/59 [00:18<00:00,  3.19it/s, v_num=5-51, g_l1_loss=0.333]
#                                                                                 Epoch 4, global step 490: 'val_loss' reached 0.40340 (best 0.40340), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.4034-epoch=4.ckpt' as top 3
# Epoch 9:  83%|████▏| 49/59 [00:17<00:03,  2.84it/s, v_num=5-51, g_l1_loss=0.330]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 9:  85%|████▏| 50/59 [00:17<00:03,  2.85it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 9:  86%|████▎| 51/59 [00:17<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 9:  88%|████▍| 52/59 [00:17<00:02,  2.93it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 9:  90%|████▍| 53/59 [00:17<00:02,  2.96it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 9:  92%|████▌| 54/59 [00:18<00:01,  3.00it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 9:  93%|████▋| 55/59 [00:18<00:01,  3.03it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 9:  95%|████▋| 56/59 [00:18<00:00,  3.07it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 9:  97%|████▊| 57/59 [00:18<00:00,  3.11it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 9:  98%|████▉| 58/59 [00:18<00:00,  3.14it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 9: 100%|█████| 59/59 [00:18<00:00,  3.18it/s, v_num=5-51, g_l1_loss=0.330]
#                                                                                 Epoch 9, global step 980: 'val_loss' reached 0.39290 (best 0.39290), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3929-epoch=9.ckpt' as top 3
# Epoch 14:  83%|███▎| 49/59 [00:17<00:03,  2.83it/s, v_num=5-51, g_l1_loss=0.318]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 14:  85%|███▍| 50/59 [00:17<00:03,  2.84it/s, v_num=5-51, g_l1_loss=0.318]
# Epoch 14:  86%|███▍| 51/59 [00:17<00:02,  2.88it/s, v_num=5-51, g_l1_loss=0.318]
# Epoch 14:  88%|███▌| 52/59 [00:17<00:02,  2.92it/s, v_num=5-51, g_l1_loss=0.318]
# Epoch 14:  90%|███▌| 53/59 [00:17<00:02,  2.95it/s, v_num=5-51, g_l1_loss=0.318]
# Epoch 14:  92%|███▋| 54/59 [00:18<00:01,  2.99it/s, v_num=5-51, g_l1_loss=0.318]
# Epoch 14:  93%|███▋| 55/59 [00:18<00:01,  3.02it/s, v_num=5-51, g_l1_loss=0.318]
# Epoch 14:  95%|███▊| 56/59 [00:18<00:00,  3.06it/s, v_num=5-51, g_l1_loss=0.318]
# Epoch 14:  97%|███▊| 57/59 [00:18<00:00,  3.09it/s, v_num=5-51, g_l1_loss=0.318]
# Epoch 14:  98%|███▉| 58/59 [00:18<00:00,  3.13it/s, v_num=5-51, g_l1_loss=0.318]
# Epoch 14: 100%|████| 59/59 [00:18<00:00,  3.17it/s, v_num=5-51, g_l1_loss=0.318]
#                                                                                 Epoch 14, global step 1470: 'val_loss' reached 0.38745 (best 0.38745), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3875-epoch=14.ckpt' as top 3
# Epoch 19:  83%|███▎| 49/59 [00:17<00:03,  2.81it/s, v_num=5-51, g_l1_loss=0.311]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 19:  85%|███▍| 50/59 [00:17<00:03,  2.82it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 19:  86%|███▍| 51/59 [00:17<00:02,  2.85it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 19:  88%|███▌| 52/59 [00:17<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 19:  90%|███▌| 53/59 [00:18<00:02,  2.93it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 19:  92%|███▋| 54/59 [00:18<00:01,  2.97it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 19:  93%|███▋| 55/59 [00:18<00:01,  3.00it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 19:  95%|███▊| 56/59 [00:18<00:00,  3.04it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 19:  97%|███▊| 57/59 [00:18<00:00,  3.07it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 19:  98%|███▉| 58/59 [00:18<00:00,  3.10it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 19: 100%|████| 59/59 [00:18<00:00,  3.14it/s, v_num=5-51, g_l1_loss=0.311]
#                                                                                 Epoch 19, global step 1960: 'val_loss' reached 0.38033 (best 0.38033), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3803-epoch=19.ckpt' as top 3
# Epoch 24:  83%|███▎| 49/59 [00:17<00:03,  2.84it/s, v_num=5-51, g_l1_loss=0.294]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 24:  85%|███▍| 50/59 [00:17<00:03,  2.84it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 24:  86%|███▍| 51/59 [00:17<00:02,  2.88it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 24:  88%|███▌| 52/59 [00:17<00:02,  2.91it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 24:  90%|███▌| 53/59 [00:17<00:02,  2.95it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 24:  92%|███▋| 54/59 [00:18<00:01,  2.99it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 24:  93%|███▋| 55/59 [00:18<00:01,  3.03it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 24:  95%|███▊| 56/59 [00:18<00:00,  3.06it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 24:  97%|███▊| 57/59 [00:18<00:00,  3.10it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 24:  98%|███▉| 58/59 [00:18<00:00,  3.13it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 24: 100%|████| 59/59 [00:18<00:00,  3.16it/s, v_num=5-51, g_l1_loss=0.294]
#                                                                                 Epoch 24, global step 2450: 'val_loss' reached 0.37372 (best 0.37372), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3737-epoch=24.ckpt' as top 3
# Epoch 29:  83%|███▎| 49/59 [00:17<00:03,  2.85it/s, v_num=5-51, g_l1_loss=0.323]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 29:  85%|███▍| 50/59 [00:17<00:03,  2.86it/s, v_num=5-51, g_l1_loss=0.323]
# Epoch 29:  86%|███▍| 51/59 [00:17<00:02,  2.90it/s, v_num=5-51, g_l1_loss=0.323]
# Epoch 29:  88%|███▌| 52/59 [00:17<00:02,  2.94it/s, v_num=5-51, g_l1_loss=0.323]
# Epoch 29:  90%|███▌| 53/59 [00:17<00:02,  2.97it/s, v_num=5-51, g_l1_loss=0.323]
# Epoch 29:  92%|███▋| 54/59 [00:17<00:01,  3.01it/s, v_num=5-51, g_l1_loss=0.323]
# Epoch 29:  93%|███▋| 55/59 [00:18<00:01,  3.05it/s, v_num=5-51, g_l1_loss=0.323]
# Epoch 29:  95%|███▊| 56/59 [00:18<00:00,  3.08it/s, v_num=5-51, g_l1_loss=0.323]
# Epoch 29:  97%|███▊| 57/59 [00:18<00:00,  3.12it/s, v_num=5-51, g_l1_loss=0.323]
# Epoch 29:  98%|███▉| 58/59 [00:18<00:00,  3.16it/s, v_num=5-51, g_l1_loss=0.323]
# Epoch 29: 100%|████| 59/59 [00:18<00:00,  3.20it/s, v_num=5-51, g_l1_loss=0.323]
#                                                                                 Epoch 29, global step 2940: 'val_loss' reached 0.37637 (best 0.37372), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3764-epoch=29.ckpt' as top 3
# Epoch 34:  83%|███▎| 49/59 [00:17<00:03,  2.77it/s, v_num=5-51, g_l1_loss=0.304]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 34:  85%|███▍| 50/59 [00:18<00:03,  2.78it/s, v_num=5-51, g_l1_loss=0.304]
# Epoch 34:  86%|███▍| 51/59 [00:18<00:02,  2.82it/s, v_num=5-51, g_l1_loss=0.304]
# Epoch 34:  88%|███▌| 52/59 [00:18<00:02,  2.85it/s, v_num=5-51, g_l1_loss=0.304]
# Epoch 34:  90%|███▌| 53/59 [00:18<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.304]
# Epoch 34:  92%|███▋| 54/59 [00:18<00:01,  2.93it/s, v_num=5-51, g_l1_loss=0.304]
# Epoch 34:  93%|███▋| 55/59 [00:18<00:01,  2.96it/s, v_num=5-51, g_l1_loss=0.304]
# Epoch 34:  95%|███▊| 56/59 [00:18<00:01,  3.00it/s, v_num=5-51, g_l1_loss=0.304]
# Epoch 34:  97%|███▊| 57/59 [00:18<00:00,  3.03it/s, v_num=5-51, g_l1_loss=0.304]
# Epoch 34:  98%|███▉| 58/59 [00:18<00:00,  3.06it/s, v_num=5-51, g_l1_loss=0.304]
# Epoch 34: 100%|████| 59/59 [00:19<00:00,  3.10it/s, v_num=5-51, g_l1_loss=0.304]
#                                                                                 Epoch 34, global step 3430: 'val_loss' reached 0.37273 (best 0.37273), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3727-epoch=34.ckpt' as top 3
# Epoch 39:  83%|███▎| 49/59 [00:17<00:03,  2.84it/s, v_num=5-51, g_l1_loss=0.298]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 39:  85%|███▍| 50/59 [00:17<00:03,  2.85it/s, v_num=5-51, g_l1_loss=0.298]
# Epoch 39:  86%|███▍| 51/59 [00:17<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.298]
# Epoch 39:  88%|███▌| 52/59 [00:17<00:02,  2.93it/s, v_num=5-51, g_l1_loss=0.298]
# Epoch 39:  90%|███▌| 53/59 [00:17<00:02,  2.97it/s, v_num=5-51, g_l1_loss=0.298]
# Epoch 39:  92%|███▋| 54/59 [00:17<00:01,  3.01it/s, v_num=5-51, g_l1_loss=0.298]
# Epoch 39:  93%|███▋| 55/59 [00:18<00:01,  3.04it/s, v_num=5-51, g_l1_loss=0.298]
# Epoch 39:  95%|███▊| 56/59 [00:18<00:00,  3.08it/s, v_num=5-51, g_l1_loss=0.298]
# Epoch 39:  97%|███▊| 57/59 [00:18<00:00,  3.12it/s, v_num=5-51, g_l1_loss=0.298]
# Epoch 39:  98%|███▉| 58/59 [00:18<00:00,  3.15it/s, v_num=5-51, g_l1_loss=0.298]
# Epoch 39: 100%|████| 59/59 [00:18<00:00,  3.19it/s, v_num=5-51, g_l1_loss=0.298]
#                                                                                 Epoch 39, global step 3920: 'val_loss' reached 0.36926 (best 0.36926), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3693-epoch=39.ckpt' as top 3
# Epoch 44:  83%|███▎| 49/59 [00:17<00:03,  2.74it/s, v_num=5-51, g_l1_loss=0.312]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 44:  85%|███▍| 50/59 [00:18<00:03,  2.75it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 44:  86%|███▍| 51/59 [00:18<00:02,  2.79it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 44:  88%|███▌| 52/59 [00:18<00:02,  2.83it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 44:  90%|███▌| 53/59 [00:18<00:02,  2.86it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 44:  92%|███▋| 54/59 [00:18<00:01,  2.90it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 44:  93%|███▋| 55/59 [00:18<00:01,  2.93it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 44:  95%|███▊| 56/59 [00:18<00:01,  2.97it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 44:  97%|███▊| 57/59 [00:18<00:00,  3.00it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 44:  98%|███▉| 58/59 [00:19<00:00,  3.04it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 44: 100%|████| 59/59 [00:19<00:00,  3.08it/s, v_num=5-51, g_l1_loss=0.312]
#                                                                                 Epoch 44, global step 4410: 'val_loss' reached 0.37178 (best 0.36926), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3718-epoch=44.ckpt' as top 3
# Epoch 49:  83%|███▎| 49/59 [00:17<00:03,  2.75it/s, v_num=5-51, g_l1_loss=0.287]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 49:  85%|███▍| 50/59 [00:18<00:03,  2.77it/s, v_num=5-51, g_l1_loss=0.287]
# Epoch 49:  86%|███▍| 51/59 [00:18<00:02,  2.81it/s, v_num=5-51, g_l1_loss=0.287]
# Epoch 49:  88%|███▌| 52/59 [00:18<00:02,  2.84it/s, v_num=5-51, g_l1_loss=0.287]
# Epoch 49:  90%|███▌| 53/59 [00:18<00:02,  2.87it/s, v_num=5-51, g_l1_loss=0.287]
# Epoch 49:  92%|███▋| 54/59 [00:18<00:01,  2.90it/s, v_num=5-51, g_l1_loss=0.287]
# Epoch 49:  93%|███▋| 55/59 [00:18<00:01,  2.94it/s, v_num=5-51, g_l1_loss=0.287]
# Epoch 49:  95%|███▊| 56/59 [00:18<00:01,  2.97it/s, v_num=5-51, g_l1_loss=0.287]
# Epoch 49:  97%|███▊| 57/59 [00:18<00:00,  3.01it/s, v_num=5-51, g_l1_loss=0.287]
# Epoch 49:  98%|███▉| 58/59 [00:19<00:00,  3.05it/s, v_num=5-51, g_l1_loss=0.287]
# Epoch 49: 100%|████| 59/59 [00:19<00:00,  3.09it/s, v_num=5-51, g_l1_loss=0.287]
#                                                                                 Epoch 49, global step 4900: 'val_loss' reached 0.37118 (best 0.36926), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3712-epoch=49.ckpt' as top 3
# Epoch 54:  83%|███▎| 49/59 [00:18<00:03,  2.70it/s, v_num=5-51, g_l1_loss=0.308]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 54:  85%|███▍| 50/59 [00:18<00:03,  2.71it/s, v_num=5-51, g_l1_loss=0.308]
# Epoch 54:  86%|███▍| 51/59 [00:18<00:02,  2.74it/s, v_num=5-51, g_l1_loss=0.308]
# Epoch 54:  88%|███▌| 52/59 [00:18<00:02,  2.78it/s, v_num=5-51, g_l1_loss=0.308]
# Epoch 54:  90%|███▌| 53/59 [00:18<00:02,  2.82it/s, v_num=5-51, g_l1_loss=0.308]
# Epoch 54:  92%|███▋| 54/59 [00:18<00:01,  2.85it/s, v_num=5-51, g_l1_loss=0.308]
# Epoch 54:  93%|███▋| 55/59 [00:19<00:01,  2.89it/s, v_num=5-51, g_l1_loss=0.308]
# Epoch 54:  95%|███▊| 56/59 [00:19<00:01,  2.93it/s, v_num=5-51, g_l1_loss=0.308]
# Epoch 54:  97%|███▊| 57/59 [00:19<00:00,  2.95it/s, v_num=5-51, g_l1_loss=0.308]
# Epoch 54:  98%|███▉| 58/59 [00:19<00:00,  2.98it/s, v_num=5-51, g_l1_loss=0.308]
# Epoch 54: 100%|████| 59/59 [00:19<00:00,  3.02it/s, v_num=5-51, g_l1_loss=0.308]
#                                                                                 Epoch 54, global step 5390: 'val_loss' reached 0.36910 (best 0.36910), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3691-epoch=54.ckpt' as top 3
# Epoch 59:  83%|███▎| 49/59 [00:18<00:03,  2.71it/s, v_num=5-51, g_l1_loss=0.311]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 59:  85%|███▍| 50/59 [00:18<00:03,  2.73it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 59:  86%|███▍| 51/59 [00:18<00:02,  2.77it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 59:  88%|███▌| 52/59 [00:18<00:02,  2.80it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 59:  90%|███▌| 53/59 [00:18<00:02,  2.84it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 59:  92%|███▋| 54/59 [00:18<00:01,  2.88it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 59:  93%|███▋| 55/59 [00:18<00:01,  2.91it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 59:  95%|███▊| 56/59 [00:18<00:01,  2.95it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 59:  97%|███▊| 57/59 [00:19<00:00,  2.99it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 59:  98%|███▉| 58/59 [00:19<00:00,  3.02it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 59: 100%|████| 59/59 [00:19<00:00,  3.06it/s, v_num=5-51, g_l1_loss=0.311]
#                                                                                 Epoch 59, global step 5880: 'val_loss' reached 0.36657 (best 0.36657), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3666-epoch=59.ckpt' as top 3
# Epoch 64:  83%|███▎| 49/59 [00:17<00:03,  2.77it/s, v_num=5-51, g_l1_loss=0.315]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 64:  85%|███▍| 50/59 [00:17<00:03,  2.78it/s, v_num=5-51, g_l1_loss=0.315]
# Epoch 64:  86%|███▍| 51/59 [00:18<00:02,  2.82it/s, v_num=5-51, g_l1_loss=0.315]
# Epoch 64:  88%|███▌| 52/59 [00:18<00:02,  2.86it/s, v_num=5-51, g_l1_loss=0.315]
# Epoch 64:  90%|███▌| 53/59 [00:18<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.315]
# Epoch 64:  92%|███▋| 54/59 [00:18<00:01,  2.93it/s, v_num=5-51, g_l1_loss=0.315]
# Epoch 64:  93%|███▋| 55/59 [00:18<00:01,  2.97it/s, v_num=5-51, g_l1_loss=0.315]
# Epoch 64:  95%|███▊| 56/59 [00:18<00:00,  3.00it/s, v_num=5-51, g_l1_loss=0.315]
# Epoch 64:  97%|███▊| 57/59 [00:18<00:00,  3.02it/s, v_num=5-51, g_l1_loss=0.315]
# Epoch 64:  98%|███▉| 58/59 [00:18<00:00,  3.06it/s, v_num=5-51, g_l1_loss=0.315]
# Epoch 64: 100%|████| 59/59 [00:19<00:00,  3.10it/s, v_num=5-51, g_l1_loss=0.315]
#                                                                                 Epoch 64, global step 6370: 'val_loss' reached 0.36838 (best 0.36657), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3684-epoch=64.ckpt' as top 3
# Epoch 69:  83%|███▎| 49/59 [00:17<00:03,  2.76it/s, v_num=5-51, g_l1_loss=0.332]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 69:  85%|███▍| 50/59 [00:18<00:03,  2.77it/s, v_num=5-51, g_l1_loss=0.332]
# Epoch 69:  86%|███▍| 51/59 [00:18<00:02,  2.81it/s, v_num=5-51, g_l1_loss=0.332]
# Epoch 69:  88%|███▌| 52/59 [00:18<00:02,  2.85it/s, v_num=5-51, g_l1_loss=0.332]
# Epoch 69:  90%|███▌| 53/59 [00:18<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.332]
# Epoch 69:  92%|███▋| 54/59 [00:18<00:01,  2.92it/s, v_num=5-51, g_l1_loss=0.332]
# Epoch 69:  93%|███▋| 55/59 [00:18<00:01,  2.96it/s, v_num=5-51, g_l1_loss=0.332]
# Epoch 69:  95%|███▊| 56/59 [00:18<00:01,  3.00it/s, v_num=5-51, g_l1_loss=0.332]
# Epoch 69:  97%|███▊| 57/59 [00:18<00:00,  3.03it/s, v_num=5-51, g_l1_loss=0.332]
# Epoch 69:  98%|███▉| 58/59 [00:18<00:00,  3.07it/s, v_num=5-51, g_l1_loss=0.332]
# Epoch 69: 100%|████| 59/59 [00:18<00:00,  3.11it/s, v_num=5-51, g_l1_loss=0.332]
#                                                                                 Epoch 69, global step 6860: 'val_loss' was not in top 3
# Epoch 74:  83%|███▎| 49/59 [00:17<00:03,  2.84it/s, v_num=5-51, g_l1_loss=0.294]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 74:  85%|███▍| 50/59 [00:17<00:03,  2.86it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 74:  86%|███▍| 51/59 [00:17<00:02,  2.90it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 74:  88%|███▌| 52/59 [00:17<00:02,  2.94it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 74:  90%|███▌| 53/59 [00:17<00:02,  2.97it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 74:  92%|███▋| 54/59 [00:17<00:01,  3.01it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 74:  93%|███▋| 55/59 [00:18<00:01,  3.05it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 74:  95%|███▊| 56/59 [00:18<00:00,  3.09it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 74:  97%|███▊| 57/59 [00:18<00:00,  3.12it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 74:  98%|███▉| 58/59 [00:18<00:00,  3.16it/s, v_num=5-51, g_l1_loss=0.294]
# Epoch 74: 100%|████| 59/59 [00:18<00:00,  3.20it/s, v_num=5-51, g_l1_loss=0.294]
#                                                                                 Epoch 74, global step 7350: 'val_loss' reached 0.36568 (best 0.36568), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3657-epoch=74.ckpt' as top 3
# Epoch 79:  83%|███▎| 49/59 [00:18<00:03,  2.69it/s, v_num=5-51, g_l1_loss=0.306]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 79:  85%|███▍| 50/59 [00:18<00:03,  2.71it/s, v_num=5-51, g_l1_loss=0.306]
# Epoch 79:  86%|███▍| 51/59 [00:18<00:02,  2.75it/s, v_num=5-51, g_l1_loss=0.306]
# Epoch 79:  88%|███▌| 52/59 [00:18<00:02,  2.78it/s, v_num=5-51, g_l1_loss=0.306]
# Epoch 79:  90%|███▌| 53/59 [00:18<00:02,  2.82it/s, v_num=5-51, g_l1_loss=0.306]
# Epoch 79:  92%|███▋| 54/59 [00:18<00:01,  2.86it/s, v_num=5-51, g_l1_loss=0.306]
# Epoch 79:  93%|███▋| 55/59 [00:18<00:01,  2.90it/s, v_num=5-51, g_l1_loss=0.306]
# Epoch 79:  95%|███▊| 56/59 [00:19<00:01,  2.93it/s, v_num=5-51, g_l1_loss=0.306]
# Epoch 79:  97%|███▊| 57/59 [00:19<00:00,  2.97it/s, v_num=5-51, g_l1_loss=0.306]
# Epoch 79:  98%|███▉| 58/59 [00:19<00:00,  3.00it/s, v_num=5-51, g_l1_loss=0.306]
# Epoch 79: 100%|████| 59/59 [00:19<00:00,  3.04it/s, v_num=5-51, g_l1_loss=0.306]
#                                                                                 Epoch 79, global step 7840: 'val_loss' reached 0.36703 (best 0.36568), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3670-epoch=79.ckpt' as top 3
# Epoch 84:  83%|███▎| 49/59 [00:17<00:03,  2.78it/s, v_num=5-51, g_l1_loss=0.311]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 84:  85%|███▍| 50/59 [00:17<00:03,  2.79it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 84:  86%|███▍| 51/59 [00:18<00:02,  2.83it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 84:  88%|███▌| 52/59 [00:18<00:02,  2.87it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 84:  90%|███▌| 53/59 [00:18<00:02,  2.91it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 84:  92%|███▋| 54/59 [00:18<00:01,  2.94it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 84:  93%|███▋| 55/59 [00:18<00:01,  2.98it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 84:  95%|███▊| 56/59 [00:18<00:00,  3.02it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 84:  97%|███▊| 57/59 [00:18<00:00,  3.05it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 84:  98%|███▉| 58/59 [00:18<00:00,  3.09it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 84: 100%|████| 59/59 [00:18<00:00,  3.13it/s, v_num=5-51, g_l1_loss=0.311]
#                                                                                 Epoch 84, global step 8330: 'val_loss' reached 0.36653 (best 0.36568), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3665-epoch=84.ckpt' as top 3
# Epoch 89:  83%|███▎| 49/59 [00:17<00:03,  2.74it/s, v_num=5-51, g_l1_loss=0.302]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 89:  85%|███▍| 50/59 [00:18<00:03,  2.75it/s, v_num=5-51, g_l1_loss=0.302]
# Epoch 89:  86%|███▍| 51/59 [00:18<00:02,  2.79it/s, v_num=5-51, g_l1_loss=0.302]
# Epoch 89:  88%|███▌| 52/59 [00:18<00:02,  2.83it/s, v_num=5-51, g_l1_loss=0.302]
# Epoch 89:  90%|███▌| 53/59 [00:18<00:02,  2.87it/s, v_num=5-51, g_l1_loss=0.302]
# Epoch 89:  92%|███▋| 54/59 [00:18<00:01,  2.90it/s, v_num=5-51, g_l1_loss=0.302]
# Epoch 89:  93%|███▋| 55/59 [00:18<00:01,  2.94it/s, v_num=5-51, g_l1_loss=0.302]
# Epoch 89:  95%|███▊| 56/59 [00:18<00:01,  2.98it/s, v_num=5-51, g_l1_loss=0.302]
# Epoch 89:  97%|███▊| 57/59 [00:18<00:00,  3.01it/s, v_num=5-51, g_l1_loss=0.302]
# Epoch 89:  98%|███▉| 58/59 [00:19<00:00,  3.05it/s, v_num=5-51, g_l1_loss=0.302]
# Epoch 89: 100%|████| 59/59 [00:19<00:00,  3.09it/s, v_num=5-51, g_l1_loss=0.302]
#                                                                                 Epoch 89, global step 8820: 'val_loss' reached 0.36610 (best 0.36568), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3661-epoch=89.ckpt' as top 3
# Epoch 94:  83%|███▎| 49/59 [00:17<00:03,  2.73it/s, v_num=5-51, g_l1_loss=0.330]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 94:  85%|███▍| 50/59 [00:18<00:03,  2.74it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 94:  86%|███▍| 51/59 [00:18<00:02,  2.78it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 94:  88%|███▌| 52/59 [00:18<00:02,  2.82it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 94:  90%|███▌| 53/59 [00:18<00:02,  2.86it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 94:  92%|███▋| 54/59 [00:18<00:01,  2.89it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 94:  93%|███▋| 55/59 [00:18<00:01,  2.93it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 94:  95%|███▊| 56/59 [00:18<00:01,  2.95it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 94:  97%|███▊| 57/59 [00:19<00:00,  2.99it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 94:  98%|███▉| 58/59 [00:19<00:00,  3.02it/s, v_num=5-51, g_l1_loss=0.330]
# Epoch 94: 100%|████| 59/59 [00:19<00:00,  3.06it/s, v_num=5-51, g_l1_loss=0.330]
#                                                                                 Epoch 94, global step 9310: 'val_loss' was not in top 3
# Epoch 99:  83%|███▎| 49/59 [00:18<00:03,  2.68it/s, v_num=5-51, g_l1_loss=0.311]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 99:  85%|███▍| 50/59 [00:18<00:03,  2.69it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 99:  86%|███▍| 51/59 [00:18<00:02,  2.73it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 99:  88%|███▌| 52/59 [00:18<00:02,  2.77it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 99:  90%|███▌| 53/59 [00:18<00:02,  2.80it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 99:  92%|███▋| 54/59 [00:19<00:01,  2.84it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 99:  93%|███▋| 55/59 [00:19<00:01,  2.88it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 99:  95%|███▊| 56/59 [00:19<00:01,  2.91it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 99:  97%|███▊| 57/59 [00:19<00:00,  2.95it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 99:  98%|███▉| 58/59 [00:19<00:00,  2.98it/s, v_num=5-51, g_l1_loss=0.311]
# Epoch 99: 100%|████| 59/59 [00:19<00:00,  3.02it/s, v_num=5-51, g_l1_loss=0.311]
#                                                                                 Epoch 99, global step 9800: 'val_loss' reached 0.36520 (best 0.36520), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3652-epoch=99.ckpt' as top 3
# Epoch 104:  83%|██▍| 49/59 [00:17<00:03,  2.84it/s, v_num=5-51, g_l1_loss=0.289]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 104:  85%|██▌| 50/59 [00:17<00:03,  2.86it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 104:  86%|██▌| 51/59 [00:17<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 104:  88%|██▋| 52/59 [00:17<00:02,  2.93it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 104:  90%|██▋| 53/59 [00:17<00:02,  2.97it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 104:  92%|██▋| 54/59 [00:17<00:01,  3.01it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 104:  93%|██▊| 55/59 [00:18<00:01,  3.05it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 104:  95%|██▊| 56/59 [00:18<00:00,  3.08it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 104:  97%|██▉| 57/59 [00:18<00:00,  3.12it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 104:  98%|██▉| 58/59 [00:18<00:00,  3.15it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 104: 100%|███| 59/59 [00:18<00:00,  3.20it/s, v_num=5-51, g_l1_loss=0.289]
#                                                                                 Epoch 104, global step 10290: 'val_loss' reached 0.36484 (best 0.36484), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3648-epoch=104.ckpt' as top 3
# Epoch 109:  83%|██▍| 49/59 [00:17<00:03,  2.83it/s, v_num=5-51, g_l1_loss=0.289]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 109:  85%|██▌| 50/59 [00:17<00:03,  2.85it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 109:  86%|██▌| 51/59 [00:17<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 109:  88%|██▋| 52/59 [00:17<00:02,  2.92it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 109:  90%|██▋| 53/59 [00:17<00:02,  2.96it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 109:  92%|██▋| 54/59 [00:18<00:01,  3.00it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 109:  93%|██▊| 55/59 [00:18<00:01,  3.04it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 109:  95%|██▊| 56/59 [00:18<00:00,  3.07it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 109:  97%|██▉| 57/59 [00:18<00:00,  3.11it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 109:  98%|██▉| 58/59 [00:18<00:00,  3.15it/s, v_num=5-51, g_l1_loss=0.289]
# Epoch 109: 100%|███| 59/59 [00:18<00:00,  3.19it/s, v_num=5-51, g_l1_loss=0.289]
#                                                                                 Epoch 109, global step 10780: 'val_loss' reached 0.36107 (best 0.36107), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3611-epoch=109.ckpt' as top 3
# Epoch 114:  83%|██▍| 49/59 [00:17<00:03,  2.84it/s, v_num=5-51, g_l1_loss=0.316]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 114:  85%|██▌| 50/59 [00:17<00:03,  2.85it/s, v_num=5-51, g_l1_loss=0.316]
# Epoch 114:  86%|██▌| 51/59 [00:17<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.316]
# Epoch 114:  88%|██▋| 52/59 [00:17<00:02,  2.93it/s, v_num=5-51, g_l1_loss=0.316]
# Epoch 114:  90%|██▋| 53/59 [00:17<00:02,  2.96it/s, v_num=5-51, g_l1_loss=0.316]
# Epoch 114:  92%|██▋| 54/59 [00:17<00:01,  3.00it/s, v_num=5-51, g_l1_loss=0.316]
# Epoch 114:  93%|██▊| 55/59 [00:18<00:01,  3.04it/s, v_num=5-51, g_l1_loss=0.316]
# Epoch 114:  95%|██▊| 56/59 [00:18<00:00,  3.08it/s, v_num=5-51, g_l1_loss=0.316]
# Epoch 114:  97%|██▉| 57/59 [00:18<00:00,  3.11it/s, v_num=5-51, g_l1_loss=0.316]
# Epoch 114:  98%|██▉| 58/59 [00:18<00:00,  3.15it/s, v_num=5-51, g_l1_loss=0.316]
# Epoch 114: 100%|███| 59/59 [00:18<00:00,  3.19it/s, v_num=5-51, g_l1_loss=0.316]
#                                                                                 Epoch 114, global step 11270: 'val_loss' reached 0.36189 (best 0.36107), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3619-epoch=114.ckpt' as top 3
# Epoch 119:  83%|██▍| 49/59 [00:17<00:03,  2.85it/s, v_num=5-51, g_l1_loss=0.303]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 119:  85%|██▌| 50/59 [00:17<00:03,  2.86it/s, v_num=5-51, g_l1_loss=0.303]
# Epoch 119:  86%|██▌| 51/59 [00:17<00:02,  2.90it/s, v_num=5-51, g_l1_loss=0.303]
# Epoch 119:  88%|██▋| 52/59 [00:17<00:02,  2.94it/s, v_num=5-51, g_l1_loss=0.303]
# Epoch 119:  90%|██▋| 53/59 [00:17<00:02,  2.98it/s, v_num=5-51, g_l1_loss=0.303]
# Epoch 119:  92%|██▋| 54/59 [00:17<00:01,  3.01it/s, v_num=5-51, g_l1_loss=0.303]
# Epoch 119:  93%|██▊| 55/59 [00:18<00:01,  3.05it/s, v_num=5-51, g_l1_loss=0.303]
# Epoch 119:  95%|██▊| 56/59 [00:18<00:00,  3.09it/s, v_num=5-51, g_l1_loss=0.303]
# Epoch 119:  97%|██▉| 57/59 [00:18<00:00,  3.12it/s, v_num=5-51, g_l1_loss=0.303]
# Epoch 119:  98%|██▉| 58/59 [00:18<00:00,  3.16it/s, v_num=5-51, g_l1_loss=0.303]
# Epoch 119: 100%|███| 59/59 [00:18<00:00,  3.20it/s, v_num=5-51, g_l1_loss=0.303]
#                                                                                 Epoch 119, global step 11760: 'val_loss' reached 0.36181 (best 0.36107), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3618-epoch=119.ckpt' as top 3
# Epoch 124:  83%|██▍| 49/59 [00:17<00:03,  2.84it/s, v_num=5-51, g_l1_loss=0.297]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 124:  85%|██▌| 50/59 [00:17<00:03,  2.85it/s, v_num=5-51, g_l1_loss=0.297]
# Epoch 124:  86%|██▌| 51/59 [00:17<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.297]
# Epoch 124:  88%|██▋| 52/59 [00:17<00:02,  2.93it/s, v_num=5-51, g_l1_loss=0.297]
# Epoch 124:  90%|██▋| 53/59 [00:17<00:02,  2.97it/s, v_num=5-51, g_l1_loss=0.297]
# Epoch 124:  92%|██▋| 54/59 [00:17<00:01,  3.01it/s, v_num=5-51, g_l1_loss=0.297]
# Epoch 124:  93%|██▊| 55/59 [00:18<00:01,  3.04it/s, v_num=5-51, g_l1_loss=0.297]
# Epoch 124:  95%|██▊| 56/59 [00:18<00:00,  3.08it/s, v_num=5-51, g_l1_loss=0.297]
# Epoch 124:  97%|██▉| 57/59 [00:18<00:00,  3.12it/s, v_num=5-51, g_l1_loss=0.297]
# Epoch 124:  98%|██▉| 58/59 [00:18<00:00,  3.15it/s, v_num=5-51, g_l1_loss=0.297]
# Epoch 124: 100%|███| 59/59 [00:18<00:00,  3.19it/s, v_num=5-51, g_l1_loss=0.297]
#                                                                                 Epoch 124, global step 12250: 'val_loss' was not in top 3
# Epoch 129:  83%|██▍| 49/59 [00:17<00:03,  2.84it/s, v_num=5-51, g_l1_loss=0.290]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 129:  85%|██▌| 50/59 [00:17<00:03,  2.85it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 129:  86%|██▌| 51/59 [00:17<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 129:  88%|██▋| 52/59 [00:17<00:02,  2.93it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 129:  90%|██▋| 53/59 [00:17<00:02,  2.97it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 129:  92%|██▋| 54/59 [00:17<00:01,  3.01it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 129:  93%|██▊| 55/59 [00:18<00:01,  3.05it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 129:  95%|██▊| 56/59 [00:18<00:00,  3.08it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 129:  97%|██▉| 57/59 [00:18<00:00,  3.12it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 129:  98%|██▉| 58/59 [00:18<00:00,  3.15it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 129: 100%|███| 59/59 [00:18<00:00,  3.20it/s, v_num=5-51, g_l1_loss=0.290]
#                                                                                 Epoch 129, global step 12740: 'val_loss' was not in top 3
# Epoch 134:  83%|██▍| 49/59 [00:17<00:03,  2.80it/s, v_num=5-51, g_l1_loss=0.310]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 134:  85%|██▌| 50/59 [00:17<00:03,  2.82it/s, v_num=5-51, g_l1_loss=0.310]
# Epoch 134:  86%|██▌| 51/59 [00:17<00:02,  2.86it/s, v_num=5-51, g_l1_loss=0.310]
# Epoch 134:  88%|██▋| 52/59 [00:17<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.310]
# Epoch 134:  90%|██▋| 53/59 [00:18<00:02,  2.93it/s, v_num=5-51, g_l1_loss=0.310]
# Epoch 134:  92%|██▋| 54/59 [00:18<00:01,  2.97it/s, v_num=5-51, g_l1_loss=0.310]
# Epoch 134:  93%|██▊| 55/59 [00:18<00:01,  3.01it/s, v_num=5-51, g_l1_loss=0.310]
# Epoch 134:  95%|██▊| 56/59 [00:18<00:00,  3.04it/s, v_num=5-51, g_l1_loss=0.310]
# Epoch 134:  97%|██▉| 57/59 [00:18<00:00,  3.08it/s, v_num=5-51, g_l1_loss=0.310]
# Epoch 134:  98%|██▉| 58/59 [00:18<00:00,  3.11it/s, v_num=5-51, g_l1_loss=0.310]
# Epoch 134: 100%|███| 59/59 [00:18<00:00,  3.15it/s, v_num=5-51, g_l1_loss=0.310]
#                                                                                 Epoch 134, global step 13230: 'val_loss' reached 0.35996 (best 0.35996), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3600-epoch=134.ckpt' as top 3
# Epoch 139:  83%|██▍| 49/59 [00:17<00:03,  2.84it/s, v_num=5-51, g_l1_loss=0.312]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 139:  85%|██▌| 50/59 [00:17<00:03,  2.85it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 139:  86%|██▌| 51/59 [00:17<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 139:  88%|██▋| 52/59 [00:17<00:02,  2.93it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 139:  90%|██▋| 53/59 [00:17<00:02,  2.97it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 139:  92%|██▋| 54/59 [00:17<00:01,  3.00it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 139:  93%|██▊| 55/59 [00:18<00:01,  3.04it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 139:  95%|██▊| 56/59 [00:18<00:00,  3.08it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 139:  97%|██▉| 57/59 [00:18<00:00,  3.11it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 139:  98%|██▉| 58/59 [00:18<00:00,  3.15it/s, v_num=5-51, g_l1_loss=0.312]
# Epoch 139: 100%|███| 59/59 [00:18<00:00,  3.18it/s, v_num=5-51, g_l1_loss=0.312]
#                                                                                 Epoch 139, global step 13720: 'val_loss' was not in top 3
# Epoch 144:  83%|██▍| 49/59 [00:17<00:03,  2.85it/s, v_num=5-51, g_l1_loss=0.301]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 144:  85%|██▌| 50/59 [00:17<00:03,  2.86it/s, v_num=5-51, g_l1_loss=0.301]
# Epoch 144:  86%|██▌| 51/59 [00:17<00:02,  2.90it/s, v_num=5-51, g_l1_loss=0.301]
# Epoch 144:  88%|██▋| 52/59 [00:17<00:02,  2.94it/s, v_num=5-51, g_l1_loss=0.301]
# Epoch 144:  90%|██▋| 53/59 [00:17<00:02,  2.98it/s, v_num=5-51, g_l1_loss=0.301]
# Epoch 144:  92%|██▋| 54/59 [00:17<00:01,  3.02it/s, v_num=5-51, g_l1_loss=0.301]
# Epoch 144:  93%|██▊| 55/59 [00:18<00:01,  3.05it/s, v_num=5-51, g_l1_loss=0.301]
# Epoch 144:  95%|██▊| 56/59 [00:18<00:00,  3.09it/s, v_num=5-51, g_l1_loss=0.301]
# Epoch 144:  97%|██▉| 57/59 [00:18<00:00,  3.13it/s, v_num=5-51, g_l1_loss=0.301]
# Epoch 144:  98%|██▉| 58/59 [00:18<00:00,  3.16it/s, v_num=5-51, g_l1_loss=0.301]
# Epoch 144: 100%|███| 59/59 [00:18<00:00,  3.21it/s, v_num=5-51, g_l1_loss=0.301]
# ...
# Epoch 899:  95%|██▊| 56/59 [00:18<00:01,  2.99it/s, v_num=5-51, g_l1_loss=0.281]
# Epoch 899:  97%|██▉| 57/59 [00:18<00:00,  3.03it/s, v_num=5-51, g_l1_loss=0.281]
# Epoch 899:  98%|██▉| 58/59 [00:18<00:00,  3.07it/s, v_num=5-51, g_l1_loss=0.281]
# Epoch 899: 100%|███| 59/59 [00:18<00:00,  3.11it/s, v_num=5-51, g_l1_loss=0.281]
#                                                                                 Epoch 899, global step 88200: 'val_loss' was not in top 3
# Epoch 904:  83%|██▍| 49/59 [00:17<00:03,  2.84it/s, v_num=5-51, g_l1_loss=0.262]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 904:  85%|██▌| 50/59 [00:17<00:03,  2.85it/s, v_num=5-51, g_l1_loss=0.262]
# Epoch 904:  86%|██▌| 51/59 [00:17<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.262]
# Epoch 904:  88%|██▋| 52/59 [00:17<00:02,  2.93it/s, v_num=5-51, g_l1_loss=0.262]
# Epoch 904:  90%|██▋| 53/59 [00:17<00:02,  2.97it/s, v_num=5-51, g_l1_loss=0.262]
# Epoch 904:  92%|██▋| 54/59 [00:17<00:01,  3.01it/s, v_num=5-51, g_l1_loss=0.262]
# Epoch 904:  93%|██▊| 55/59 [00:18<00:01,  3.04it/s, v_num=5-51, g_l1_loss=0.262]
# Epoch 904:  95%|██▊| 56/59 [00:18<00:00,  3.08it/s, v_num=5-51, g_l1_loss=0.262]
# Epoch 904:  97%|██▉| 57/59 [00:18<00:00,  3.12it/s, v_num=5-51, g_l1_loss=0.262]
# Epoch 904:  98%|██▉| 58/59 [00:18<00:00,  3.15it/s, v_num=5-51, g_l1_loss=0.262]
# Epoch 904: 100%|███| 59/59 [00:18<00:00,  3.20it/s, v_num=5-51, g_l1_loss=0.262]
#                                                                                 Epoch 904, global step 88690: 'val_loss' was not in top 3
# Epoch 909:  83%|██▍| 49/59 [00:17<00:03,  2.74it/s, v_num=5-51, g_l1_loss=0.275]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 909:  85%|██▌| 50/59 [00:18<00:03,  2.76it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 909:  86%|██▌| 51/59 [00:18<00:02,  2.80it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 909:  88%|██▋| 52/59 [00:18<00:02,  2.83it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 909:  90%|██▋| 53/59 [00:18<00:02,  2.87it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 909:  92%|██▋| 54/59 [00:18<00:01,  2.91it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 909:  93%|██▊| 55/59 [00:18<00:01,  2.94it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 909:  95%|██▊| 56/59 [00:18<00:01,  2.98it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 909:  97%|██▉| 57/59 [00:18<00:00,  3.02it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 909:  98%|██▉| 58/59 [00:19<00:00,  3.05it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 909: 100%|███| 59/59 [00:19<00:00,  3.09it/s, v_num=5-51, g_l1_loss=0.275]
#                                                                                 Epoch 909, global step 89180: 'val_loss' reached 0.33306 (best 0.33197), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3331-epoch=909.ckpt' as top 3
# Epoch 914:  83%|██▍| 49/59 [00:17<00:03,  2.83it/s, v_num=5-51, g_l1_loss=0.275]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 914:  85%|██▌| 50/59 [00:17<00:03,  2.85it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 914:  86%|██▌| 51/59 [00:17<00:02,  2.88it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 914:  88%|██▋| 52/59 [00:17<00:02,  2.92it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 914:  90%|██▋| 53/59 [00:17<00:02,  2.96it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 914:  92%|██▋| 54/59 [00:18<00:01,  3.00it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 914:  93%|██▊| 55/59 [00:18<00:01,  3.03it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 914:  95%|██▊| 56/59 [00:18<00:00,  3.07it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 914:  97%|██▉| 57/59 [00:18<00:00,  3.11it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 914:  98%|██▉| 58/59 [00:18<00:00,  3.14it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 914: 100%|███| 59/59 [00:18<00:00,  3.19it/s, v_num=5-51, g_l1_loss=0.275]
#                                                                                 Epoch 914, global step 89670: 'val_loss' was not in top 3
# Epoch 919:  83%|██▍| 49/59 [00:17<00:03,  2.84it/s, v_num=5-51, g_l1_loss=0.280]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 919:  85%|██▌| 50/59 [00:17<00:03,  2.85it/s, v_num=5-51, g_l1_loss=0.280]
# Epoch 919:  86%|██▌| 51/59 [00:17<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.280]
# Epoch 919:  88%|██▋| 52/59 [00:17<00:02,  2.93it/s, v_num=5-51, g_l1_loss=0.280]
# Epoch 919:  90%|██▋| 53/59 [00:17<00:02,  2.97it/s, v_num=5-51, g_l1_loss=0.280]
# Epoch 919:  92%|██▋| 54/59 [00:17<00:01,  3.01it/s, v_num=5-51, g_l1_loss=0.280]
# Epoch 919:  93%|██▊| 55/59 [00:18<00:01,  3.04it/s, v_num=5-51, g_l1_loss=0.280]
# Epoch 919:  95%|██▊| 56/59 [00:18<00:00,  3.08it/s, v_num=5-51, g_l1_loss=0.280]
# Epoch 919:  97%|██▉| 57/59 [00:18<00:00,  3.12it/s, v_num=5-51, g_l1_loss=0.280]
# Epoch 919:  98%|██▉| 58/59 [00:18<00:00,  3.15it/s, v_num=5-51, g_l1_loss=0.280]
# Epoch 919: 100%|███| 59/59 [00:18<00:00,  3.19it/s, v_num=5-51, g_l1_loss=0.280]
#                                                                                 Epoch 919, global step 90160: 'val_loss' was not in top 3
# Epoch 924:  83%|██▍| 49/59 [00:17<00:03,  2.80it/s, v_num=5-51, g_l1_loss=0.275]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 924:  85%|██▌| 50/59 [00:17<00:03,  2.82it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 924:  86%|██▌| 51/59 [00:17<00:02,  2.85it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 924:  88%|██▋| 52/59 [00:17<00:02,  2.89it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 924:  90%|██▋| 53/59 [00:18<00:02,  2.92it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 924:  92%|██▋| 54/59 [00:18<00:01,  2.96it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 924:  93%|██▊| 55/59 [00:18<00:01,  3.00it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 924:  95%|██▊| 56/59 [00:18<00:00,  3.03it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 924:  97%|██▉| 57/59 [00:18<00:00,  3.07it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 924:  98%|██▉| 58/59 [00:18<00:00,  3.11it/s, v_num=5-51, g_l1_loss=0.275]
# Epoch 924: 100%|███| 59/59 [00:18<00:00,  3.15it/s, v_num=5-51, g_l1_loss=0.275]
#                                                                                 Epoch 924, global step 90650: 'val_loss' reached 0.33327 (best 0.33197), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3333-epoch=924.ckpt' as top 3
# Epoch 929:  83%|██▍| 49/59 [00:17<00:03,  2.85it/s, v_num=5-51, g_l1_loss=0.274]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 929:  85%|██▌| 50/59 [00:17<00:03,  2.86it/s, v_num=5-51, g_l1_loss=0.274]
# Epoch 929:  86%|██▌| 51/59 [00:17<00:02,  2.90it/s, v_num=5-51, g_l1_loss=0.274]
# Epoch 929:  88%|██▋| 52/59 [00:17<00:02,  2.94it/s, v_num=5-51, g_l1_loss=0.274]
# Epoch 929:  90%|██▋| 53/59 [00:17<00:02,  2.98it/s, v_num=5-51, g_l1_loss=0.274]
# Epoch 929:  92%|██▋| 54/59 [00:17<00:01,  3.02it/s, v_num=5-51, g_l1_loss=0.274]
# Epoch 929:  93%|██▊| 55/59 [00:18<00:01,  3.05it/s, v_num=5-51, g_l1_loss=0.274]
# Epoch 929:  95%|██▊| 56/59 [00:18<00:00,  3.09it/s, v_num=5-51, g_l1_loss=0.274]
# Epoch 929:  97%|██▉| 57/59 [00:18<00:00,  3.13it/s, v_num=5-51, g_l1_loss=0.274]
# Epoch 929:  98%|██▉| 58/59 [00:18<00:00,  3.16it/s, v_num=5-51, g_l1_loss=0.274]
# Epoch 929: 100%|███| 59/59 [00:18<00:00,  3.21it/s, v_num=5-51, g_l1_loss=0.274]
#                                                                                 Epoch 929, global step 91140: 'val_loss' was not in top 3
# Epoch 934:  83%|██▍| 49/59 [00:17<00:03,  2.83it/s, v_num=5-51, g_l1_loss=0.288]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 934:  85%|██▌| 50/59 [00:17<00:03,  2.84it/s, v_num=5-51, g_l1_loss=0.288]
# Epoch 934:  86%|██▌| 51/59 [00:17<00:02,  2.88it/s, v_num=5-51, g_l1_loss=0.288]
# Epoch 934:  88%|██▋| 52/59 [00:17<00:02,  2.92it/s, v_num=5-51, g_l1_loss=0.288]
# Epoch 934:  90%|██▋| 53/59 [00:17<00:02,  2.96it/s, v_num=5-51, g_l1_loss=0.288]
# Epoch 934:  92%|██▋| 54/59 [00:18<00:01,  2.98it/s, v_num=5-51, g_l1_loss=0.288]
# Epoch 934:  93%|██▊| 55/59 [00:18<00:01,  3.02it/s, v_num=5-51, g_l1_loss=0.288]
# Epoch 934:  95%|██▊| 56/59 [00:18<00:00,  3.05it/s, v_num=5-51, g_l1_loss=0.288]
# Epoch 934:  97%|██▉| 57/59 [00:18<00:00,  3.09it/s, v_num=5-51, g_l1_loss=0.288]
# Epoch 934:  98%|██▉| 58/59 [00:18<00:00,  3.12it/s, v_num=5-51, g_l1_loss=0.288]
# Epoch 934: 100%|███| 59/59 [00:18<00:00,  3.17it/s, v_num=5-51, g_l1_loss=0.288]
#                                                                                 Epoch 934, global step 91630: 'val_loss' was not in top 3
# Epoch 939:  83%|██▍| 49/59 [00:17<00:03,  2.78it/s, v_num=5-51, g_l1_loss=0.261]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 939:  85%|██▌| 50/59 [00:17<00:03,  2.80it/s, v_num=5-51, g_l1_loss=0.261]
# Epoch 939:  86%|██▌| 51/59 [00:17<00:02,  2.83it/s, v_num=5-51, g_l1_loss=0.261]
# Epoch 939:  88%|██▋| 52/59 [00:18<00:02,  2.87it/s, v_num=5-51, g_l1_loss=0.261]
# Epoch 939:  90%|██▋| 53/59 [00:18<00:02,  2.91it/s, v_num=5-51, g_l1_loss=0.261]
# Epoch 939:  92%|██▋| 54/59 [00:18<00:01,  2.95it/s, v_num=5-51, g_l1_loss=0.261]
# Epoch 939:  93%|██▊| 55/59 [00:18<00:01,  2.98it/s, v_num=5-51, g_l1_loss=0.261]
# Epoch 939:  95%|██▊| 56/59 [00:18<00:00,  3.02it/s, v_num=5-51, g_l1_loss=0.261]
# Epoch 939:  97%|██▉| 57/59 [00:18<00:00,  3.06it/s, v_num=5-51, g_l1_loss=0.261]
# Epoch 939:  98%|██▉| 58/59 [00:18<00:00,  3.09it/s, v_num=5-51, g_l1_loss=0.261]
# Epoch 939: 100%|███| 59/59 [00:18<00:00,  3.13it/s, v_num=5-51, g_l1_loss=0.261]
#                                                                                 Epoch 939, global step 92120: 'val_loss' was not in top 3
# Epoch 944:  83%|██▍| 49/59 [00:17<00:03,  2.81it/s, v_num=5-51, g_l1_loss=0.290]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 944:  85%|██▌| 50/59 [00:17<00:03,  2.82it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 944:  86%|██▌| 51/59 [00:17<00:02,  2.86it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 944:  88%|██▋| 52/59 [00:17<00:02,  2.90it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 944:  90%|██▋| 53/59 [00:18<00:02,  2.94it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 944:  92%|██▋| 54/59 [00:18<00:01,  2.97it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 944:  93%|██▊| 55/59 [00:18<00:01,  3.01it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 944:  95%|██▊| 56/59 [00:18<00:00,  3.05it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 944:  97%|██▉| 57/59 [00:18<00:00,  3.08it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 944:  98%|██▉| 58/59 [00:18<00:00,  3.12it/s, v_num=5-51, g_l1_loss=0.290]
# Epoch 944: 100%|███| 59/59 [00:18<00:00,  3.16it/s, v_num=5-51, g_l1_loss=0.290]
#                                                                                 Epoch 944, global step 92610: 'val_loss' reached 0.33176 (best 0.33176), saving model to '/workspace/nemo/vol/FastSpeech2/hifigan_ft/HifiGan/2023-07-28_02-15-51/checkpoints/HifiGan--val_loss=0.3318-epoch=944.ckpt' as top 3
# Epoch 949:  83%|██▍| 49/59 [00:17<00:03,  2.73it/s, v_num=5-51, g_l1_loss=0.270]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 949:  85%|██▌| 50/59 [00:18<00:03,  2.75it/s, v_num=5-51, g_l1_loss=0.270]
# Epoch 949:  86%|██▌| 51/59 [00:18<00:02,  2.78it/s, v_num=5-51, g_l1_loss=0.270]
# Epoch 949:  88%|██▋| 52/59 [00:18<00:02,  2.82it/s, v_num=5-51, g_l1_loss=0.270]
# Epoch 949:  90%|██▋| 53/59 [00:18<00:02,  2.86it/s, v_num=5-51, g_l1_loss=0.270]
# Epoch 949:  92%|██▋| 54/59 [00:18<00:01,  2.90it/s, v_num=5-51, g_l1_loss=0.270]
# Epoch 949:  93%|██▊| 55/59 [00:18<00:01,  2.93it/s, v_num=5-51, g_l1_loss=0.270]
# Epoch 949:  95%|██▊| 56/59 [00:18<00:01,  2.97it/s, v_num=5-51, g_l1_loss=0.270]
# Epoch 949:  97%|██▉| 57/59 [00:18<00:00,  3.00it/s, v_num=5-51, g_l1_loss=0.270]
# Epoch 949:  98%|██▉| 58/59 [00:19<00:00,  3.04it/s, v_num=5-51, g_l1_loss=0.270]
# Epoch 949: 100%|███| 59/59 [00:19<00:00,  3.08it/s, v_num=5-51, g_l1_loss=0.270]
#                                                                                 Epoch 949, global step 93100: 'val_loss' was not in top 3
# Epoch 954:  83%|██▍| 49/59 [00:17<00:03,  2.83it/s, v_num=5-51, g_l1_loss=0.282]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 954:  85%|██▌| 50/59 [00:17<00:03,  2.84it/s, v_num=5-51, g_l1_loss=0.282]
# Epoch 954:  86%|██▌| 51/59 [00:17<00:02,  2.88it/s, v_num=5-51, g_l1_loss=0.282]
# Epoch 954:  88%|██▋| 52/59 [00:17<00:02,  2.92it/s, v_num=5-51, g_l1_loss=0.282]
# Epoch 954:  90%|██▋| 53/59 [00:17<00:02,  2.96it/s, v_num=5-51, g_l1_loss=0.282]
# Epoch 954:  92%|██▋| 54/59 [00:18<00:01,  2.99it/s, v_num=5-51, g_l1_loss=0.282]
# Epoch 954:  93%|██▊| 55/59 [00:18<00:01,  3.03it/s, v_num=5-51, g_l1_loss=0.282]
# Epoch 954:  95%|██▊| 56/59 [00:18<00:00,  3.07it/s, v_num=5-51, g_l1_loss=0.282]
# Epoch 954:  97%|██▉| 57/59 [00:18<00:00,  3.10it/s, v_num=5-51, g_l1_loss=0.282]
# Epoch 954:  98%|██▉| 58/59 [00:18<00:00,  3.14it/s, v_num=5-51, g_l1_loss=0.282]
# Epoch 954: 100%|███| 59/59 [00:18<00:00,  3.18it/s, v_num=5-51, g_l1_loss=0.282]
#                                                                                 Epoch 954, global step 93590: 'val_loss' was not in top 3
# Epoch 959:  83%|██▍| 49/59 [00:18<00:03,  2.69it/s, v_num=5-51, g_l1_loss=0.278]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/10 [00:00<?, ?it/s]
# Epoch 959:  85%|██▌| 50/59 [00:18<00:03,  2.71it/s, v_num=5-51, g_l1_loss=0.278]
# Epoch 959:  86%|██▌| 51/59 [00:18<00:02,  2.75it/s, v_num=5-51, g_l1_loss=0.278]
# Epoch 959:  88%|██▋| 52/59 [00:18<00:02,  2.78it/s, v_num=5-51, g_l1_loss=0.278]
# Epoch 959:  90%|██▋| 53/59 [00:18<00:02,  2.82it/s, v_num=5-51, g_l1_loss=0.278]
# Epoch 959:  92%|██▋| 54/59 [00:18<00:01,  2.86it/s, v_num=5-51, g_l1_loss=0.278]
# Epoch 959:  93%|██▊| 55/59 [00:19<00:01,  2.89it/s, v_num=5-51, g_l1_loss=0.278]
# Epoch 959:  95%|██▊| 56/59 [00:19<00:01,  2.93it/s, v_num=5-51, g_l1_loss=0.278]
# Epoch 959:  97%|██▉| 57/59 [00:19<00:00,  2.96it/s, v_num=5-51, g_l1_loss=0.278]
# Epoch 959:  98%|██▉| 58/59 [00:19<00:00,  3.00it/s, v_num=5-51, g_l1_loss=0.278]
# Epoch 959: 100%|███| 59/59 [00:19<00:00,  3.04it/s, v_num=5-51, g_l1_loss=0.278]
#                                                                                 Epoch 959, global step 94080: 'val_loss' was not in top 3
# Epoch 962:  82%|██▍| 40/49 [00:14<00:03,  2.71it/s, v_num=5-51, g_l1_loss=0.281]^C
# [NeMo W 2023-07-28 07:02:39 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/call.py:48: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#       rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")

# %%
from nemo.collections.tts.torch.data import VocoderDataset
